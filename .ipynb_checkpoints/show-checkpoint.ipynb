# %%
from PIL import Image
import cv2
import torchvision.transforms as transforms
import torch.nn.functional as F
import matplotlib.pyplot as plt
import numpy as np

# %%
def imgs2video(imgs_dir, save_name):
    fps = 24
    fourcc = cv2.VideoWriter_fourcc(*'MJPG')
    video_writer = cv2.VideoWriter(save_name, fourcc, fps, (1920, 1080))
    # no glob, need number-index increasing
    imgs = glob.glob(os.path.join(imgs_dir, '*.jpg'))

    for i in range(len(imgs)):
        imgname = os.path.join(imgs_dir, 'core-{:02d}.png'.format(i))
        frame = cv2.imread(imgname)
        video_writer.write(frame)

    video_writer.release()

# %%
# img = Image.open('hsr/1/normal/3_194.jpg')
dis = cv2.imread('hsr/3/normal/3_35.jpg')[:,:,[2,1,0]]
dis = dis[100:400,1300:1700]
plt.figure(figsize=(19.2,10.8))
plt.imshow(dis)
plt.show()

# %%
print(src[320,130])
# Out:
# [255 255 255]

# %%
# img = Image.open('hsr/1/normal/3_194.jpg')
src = cv2.imread('hsr/objects/03.png')[:,:,[2,1,0]]
# src = cv2.resize(src,(int(src.shape[1]/3),int(src.shape[1]/3)))
src = src[100:320,200:500]
print(src.shape)
src_mask = np.zeros(src.shape, src.dtype)
# poly = np.array([[800,50],[800,95],[900,95],[900,50]],np.int32)
# poly = np.array([[0,0],[0,20],[10,30],[0,60],[0,120],[30,130],[50,150],[74,145],[50,140],[40,120],[50,90],[120,120],[100,80],
#                  [140,100],[140,40],[40,30],[40,0]],np.int32)
# poly = np.array([[260,100],[260,280],[440,280],[440,100]],np.int32)
# poly = np.array([[500,450],[750,800],[1250,180],[800,200]],np.int32)
# cv2.fillPoly(src_mask,[poly],(255,255,255))
for i in range(src.shape[0]):
    for j in range(src.shape[1]):
        if (src[i,j]!=255).any():
            src_mask[i,j]=[255,255,255]
plt.figure(figsize=(11.04,6.22))
plt.imshow(src)
# plt.imshow(src[src_mask])
plt.show()
# Out:
# (220, 300, 3)

# %%
center = (200,150)
output = cv2.seamlessClone(src,dis,src_mask,center,cv2.NORMAL_CLONE)
# output = cv2.add(src,dis)
plt.figure(figsize=(19.2,10.8))
plt.imshow(output)
plt.show()

# %%
transform = transforms.Compose([transforms.ToTensor()])
img = F.interpolate(transform(img).unsqueeze(0),size=[360,649])
img.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-6-5c04c4177918> in <module>
#       1 transform = transforms.Compose([transforms.ToTensor()])
# ----> 2 img = F.interpolate(transform(img).unsqueeze(0),size=[360,649])
#       3 img.show()
#
# ~/.conda/envs/lc/lib/python3.6/site-packages/torchvision/transforms/transforms.py in __call__(self, img)
#      65     def __call__(self, img):
#      66         for t in self.transforms:
# ---> 67             img = t(img)
#      68         return img
#      69
#
# ~/.conda/envs/lc/lib/python3.6/site-packages/torchvision/transforms/transforms.py in __call__(self, pic)
#     102             Tensor: Converted image.
#     103         """
# --> 104         return F.to_tensor(pic)
#     105
#     106     def __repr__(self):
#
# ~/.conda/envs/lc/lib/python3.6/site-packages/torchvision/transforms/functional.py in to_tensor(pic)
# ...

# %%
import torch
print(torch.mean(img,(1,2)))
# Out:
# tensor([0.5926, 0.5791, 0.5837])
